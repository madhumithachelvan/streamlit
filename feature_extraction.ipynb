# %%
import polars as pl
from elfen.extractor import Extractor
import pandas as pd
from pathlib import Path
import glob
import nltk

# %%
dataset = Path("dataset").glob("sub*_2_*")
dataframes = [pd.read_csv(f) for f in dataset]
merged_df = pd.concat(dataframes, ignore_index=True)
merged_df.to_csv("merged_data_2.csv", index=False)

# %%
df = pl.read_csv("merged_data_2.csv") # load our 200-text csv file here
df = df.rename({"short_text": "text"}) # change the column name of "short_text" to "text", since this is the name the "Extractor" function can identify
extractor = Extractor(data = df) # extract the features

# %%
# extract features based on intended feature groups
extractor.extract_feature_group(feature_group = ["surface",
                                                 "pos",
                                                 "lexical_richness",
                                                 "readability",
                                                 "information",
                                                 "entities",
                                                 "semantic",
                                                 "emotion",
                                                 "psycholinguistic",
                                                 "morphological",
                                                 "dependency"  
                                                 ])
print(extractor.data.head())
# Out:
# Extracting n_hedges...
# Extracting sentiment_score...
# Extracting n_positive_sentiment...
# Extracting n_negative_sentiment...
# Extracting avg_valence...
# Extracting avg_arousal...
# Extracting avg_dominance...
# Extracting n_low_valence...
# Extracting n_high_valence...
# Extracting n_low_arousal...
# Extracting n_high_arousal...
# Extracting n_low_dominance...
# Extracting n_high_dominance...
# Extracting avg_emotion_intensity...
# Extracting n_low_intensity...
# Extracting n_high_intensity...
# Extracting avg_concreteness...
# Extracting n_high_concreteness...
# Extracting n_low_concreteness...
# Extracting avg_sd_concreteness...
# Extracting n_controversial_concreteness...
# Extracting avg_aoa...
# Extracting n_high_aoa...
# Extracting n_low_aoa...
# Extracting avg_sd_aoa...
# Extracting n_controversial_aoa...
# Extracting avg_prevalence...
# Extracting n_high_prevalence...
# Extracting n_low_prevalence...
# Extracting avg_socialness...
# Extracting n_high_socialness...
# Extracting n_low_socialness...
# Extracting avg_sd_socialness...
# Extracting n_controversial_socialness...
# Extracting avg_iconicity...
# Extracting n_high_iconicity...
# Extracting n_low_iconicity...
# Extracting avg_sd_iconicity...
# Extracting n_controversial_iconicity...
# Extracting avg_sensorimotor...
# Extracting n_high_sensorimotor...
# Extracting n_low_sensorimotor...
# Extracting avg_sd_sensorimotor...
# Extracting n_controversial_sensorimotor...
# shape: (5, 1_079)
# ┌────────────┬────────────┬────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ text       ┆ id         ┆ label  ┆ data     ┆ … ┆ n_ADP_AdpT ┆ n_ADP_Adp ┆ n_ADP_Adp ┆ n_ADP_Adp │
# │ ---        ┆ ---        ┆ ---    ┆ ---      ┆   ┆ ype_Prep   ┆ Type_Post ┆ Type_Circ ┆ Type_Voc  │
# │ str        ┆ str        ┆ str    ┆ str      ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆        ┆          ┆   ┆ u16        ┆ u16       ┆ u16       ┆ u16       │
# ╞════════════╪════════════╪════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ Slowly and ┆ 5febe40a7f ┆ male   ┆ PAN13-EN ┆ … ┆ 0          ┆ 0         ┆ 0         ┆ 0         │
# │ gradually, ┆ 4bf6f477af ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ all face…  ┆ 654d3eea9a ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │            ┆ …          ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ What a     ┆ 4168492    ┆ 1      ┆ BLOG     ┆ … ┆ 0          ┆ 0         ┆ 0         ┆ 0         │
# │ wonderful  ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ day we     ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ had. W…    ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ This text  ┆ 28c118646a ┆ male   ┆ PAN13-EN ┆ … ┆ 0          ┆ 0         ┆ 0         ┆ 0         │
# │ will       ┆ baf08b3353 ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ discuss    ┆ 5fad28820d ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ the key…   ┆ …          ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ It was a   ┆ 2036_3     ┆ Female ┆ PASTEL   ┆ … ┆ 0          ┆ 0         ┆ 0         ┆ 0         │
# │ day of sig ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ htseeing   ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ fo…        ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ it behoves ┆ 8b794cc8b9 ┆ female ┆ PAN13-EN ┆ … ┆ 0          ┆ 0         ┆ 0         ┆ 0         │
# │ on us all  ┆ 857b8704d9 ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ to make a… ┆ dc4eb5d086 ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │            ┆ …          ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
# We normalize all the values
extractor.normalize("all")

# %%
# check what our extracted feature dataset look like
extractor.data.head()
# Out:
# shape: (5, 1_079)
# ┌────────────┬────────────┬────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ text       ┆ id         ┆ label  ┆ data     ┆ … ┆ n_ADP_AdpT ┆ n_ADP_Adp ┆ n_ADP_Adp ┆ n_ADP_Adp │
# │ ---        ┆ ---        ┆ ---    ┆ ---      ┆   ┆ ype_Prep   ┆ Type_Post ┆ Type_Circ ┆ Type_Voc  │
# │ str        ┆ str        ┆ str    ┆ str      ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆        ┆          ┆   ┆ f64        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ Slowly and ┆ 5febe40a7f ┆ male   ┆ PAN13-EN ┆ … ┆ NaN        ┆ NaN       ┆ NaN       ┆ NaN       │
# │ gradually, ┆ 4bf6f477af ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ all face…  ┆ 654d3eea9a ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │            ┆ …          ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ What a     ┆ 4168492    ┆ 1      ┆ BLOG     ┆ … ┆ NaN        ┆ NaN       ┆ NaN       ┆ NaN       │
# │ wonderful  ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ day we     ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ had. W…    ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ This text  ┆ 28c118646a ┆ male   ┆ PAN13-EN ┆ … ┆ NaN        ┆ NaN       ┆ NaN       ┆ NaN       │
# │ will       ┆ baf08b3353 ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ discuss    ┆ 5fad28820d ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ the key…   ┆ …          ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ It was a   ┆ 2036_3     ┆ Female ┆ PASTEL   ┆ … ┆ NaN        ┆ NaN       ┆ NaN       ┆ NaN       │
# │ day of sig ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ htseeing   ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ fo…        ┆            ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ it behoves ┆ 8b794cc8b9 ┆ female ┆ PAN13-EN ┆ … ┆ NaN        ┆ NaN       ┆ NaN       ┆ NaN       │
# │ on us all  ┆ 857b8704d9 ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │ to make a… ┆ dc4eb5d086 ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# │            ┆ …          ┆        ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
extractor.data.schema
# Out:
# Schema([('text', String),
#         ('id', String),
#         ('label', String),
#         ('data', String),
#         ('is_attention_check', Boolean),
#         ('expected_answer', String),
#         ('nlp', Object),
#         ('raw_sequence_length', Float64),
#         ('n_tokens', Float64),
#         ('n_lemmas', Float64),
#         ('n_sentences', Float64),
#         ('n_types', Float64),
#         ('n_characters', Float64),
#         ('avg_word_length', Float64),
#         ('n_long_words', Float64),
#         ('tokens_per_sentence', Float64),
#         ('n_lexical_tokens', Float64),
#         ('pos_variability', Float64),
#         ('n_adj', Float64),
#         ('n_adp', Float64),
#         ('n_adv', Float64),
#         ('n_aux', Float64),
#         ('n_conj', Float64),
#         ('n_cconj', Float64),
#         ('n_det', Float64),
#         ('n_intj', Float64),
#         ('n_noun', Float64),
#         ('n_num', Float64),
#         ('n_part', Float64),
#         ('n_pron', Float64),
#         ('n_propn', Float64),
#         ('n_punct', Float64),
#         ('n_sconj', Float64),
#         ('n_sym', Float64),
#         ('n_verb', Float64),
#         ('n_x', Float64),
#         ('lemma_token_ratio', Float64),
#         ('ttr', Float64),
#         ('cttr', Float64),
#         ('rttr', Float64),
#         ('herdan_c', Float64),
#         ('summer_index', Float64),
#         ('dugast_u', Float64),
#         ('maas_index', Float64),
#         ('n_hapax_legomena', Float64),
#         ('n_global_lemma_hapax_legomena', Float64),
#         ('n_global_token_hapax_legomena', Float64),
#         ('lexical_density', Float64),
#         ('n_hapax_dislegomena', Float64),
#         ('n_global_lemma_hapax_dislegomena', Float64),
#         ('n_global_token_hapax_dislegomena', Float64),
#         ('tokens', List(String)),
#         ('hdd', Float32),
#         ('sichel_s', Float64),
#         ('global_sichel_s', Float64),
#         ('giroud_index', Float64),
#         ('mtld', Float32),
#         ('mattr', Float32),
#         ('msttr', Float32),
#         ('token_freqs', Object),
#         ('yule_k', Float64),
#         ('simpsons_d', Float32),
#         ('herdan_v', Float64),
#         ('n_syllables', Float64),
#         ('flesch_reading_ease', Float64),
#         ('flesch_kincaid_grade', Float64),
#         ('n_polysyllables', Float64),
#         ('smog', Float64),
#         ('ari', Float64),
#         ('cli', Float64),
#         ('gunning_fog', Float64),
#         ('lix', Float64),
#         ('rix', Float64),
#         ('n_monosyllables', Float64),
#         ('compressibility', Float64),
#         ('entropy', Float64),
#         ('n_entities', Float64),
#         ('n_org', Float64),
#         ('n_cardinal', Float64),
#         ('n_date', Float64),
#         ('n_gpe', Float64),
#         ('n_person', Float64),
#         ('n_money', Float64),
#         ('n_product', Float64),
#         ('n_time', Float64),
#         ('n_percent', Float64),
#         ('n_work_of_art', Float64),
#         ('n_quantity', Float64),
#         ('n_norp', Float64),
#         ('n_loc', Float64),
#         ('n_event', Float64),
#         ('n_ordinal', Float64),
#         ('n_fac', Float64),
#         ('n_law', Float64),
#         ('n_language', Float64),
#         ('n_hedges', Float64),
#         ('synsets', List(Int64)),
#         ('synsets_noun', List(Int64)),
#         ('synsets_verb', List(Int64)),
#         ('synsets_adj', List(Int64)),
#         ('synsets_adv', List(Int64)),
#         ('avg_n_synsets', Float64),
#         ('avg_n_synsets_noun', Float64),
#         ('avg_n_synsets_verb', Float64),
#         ('avg_n_synsets_adj', Float64),
#         ('avg_n_synsets_adv', Float64),
#         ('n_high_synsets', Float64),
#         ('n_low_synsets', Float64),
#         ('n_high_synsets_noun', Float64),
#         ('n_high_synsets_verb', Float64),
#         ('n_high_synsets_adj', Float64),
#         ('n_high_synsets_adv', Float64),
#         ('n_low_synsets_noun', Float64),
#         ('n_low_synsets_verb', Float64),
#         ('n_low_synsets_adj', Float64),
#         ('n_low_synsets_adv', Float64),
#         ('lemmas', List(String)),
#         ('n_positive_sentiment', Float64),
#         ('n_negative_sentiment', Float64),
#         ('sentiment_score', Float64),
#         ('avg_valence', Float64),
#         ('avg_arousal', Float64),
#         ('avg_dominance', Float64),
#         ('n_low_valence', Float64),
#         ('n_high_valence', Float64),
#         ('n_low_arousal', Float64),
#         ('n_high_arousal', Float64),
#         ('n_low_dominance', Float64),
#         ('n_high_dominance', Float64),
#         ('avg_intensity_anger', Float64),
#         ('avg_intensity_anticipation', Float64),
#         ('avg_intensity_disgust', Float64),
#         ('avg_intensity_fear', Float64),
#         ('avg_intensity_joy', Float64),
#         ('avg_intensity_sadness', Float64),
#         ('avg_intensity_surprise', Float64),
#         ('avg_intensity_trust', Float64),
#         ('n_low_intensity_anger', Float64),
#         ('n_low_intensity_anticipation', Float64),
#         ('n_low_intensity_disgust', Float64),
#         ('n_low_intensity_fear', Float64),
#         ('n_low_intensity_joy', Float64),
#         ('n_low_intensity_sadness', Float64),
#         ('n_low_intensity_surprise', Float64),
#         ('n_low_intensity_trust', Float64),
#         ('n_high_intensity_anger', Float64),
#         ('n_high_intensity_anticipation', Float64),
#         ('n_high_intensity_disgust', Float64),
#         ('n_high_intensity_fear', Float64),
#         ('n_high_intensity_joy', Float64),
#         ('n_high_intensity_sadness', Float64),
#         ('n_high_intensity_surprise', Float64),
#         ('n_high_intensity_trust', Float64),
#         ('tree_width', Float64),
#         ('tree_depth', Float64),
#         ('tree_branching', Float32),
#         ('ramification_factor', Float32),
#         ('n_noun_chunks', Float64),
#         ('n_dependency_acl', Float64),
#         ('n_dependency_acomp', Float64),
#         ('n_dependency_advcl', Float64),
#         ('n_dependency_advmod', Float64),
#         ('n_dependency_agent', Float64),
#         ('n_dependency_amod', Float64),
#         ('n_dependency_appos', Float64),
#         ('n_dependency_attr', Float64),
#         ('n_dependency_aux', Float64),
#         ('n_dependency_auxpass', Float64),
#         ('n_dependency_case', Float64),
#         ('n_dependency_cc', Float64),
#         ('n_dependency_ccomp', Float64),
#         ('n_dependency_compound', Float64),
#         ('n_dependency_conj', Float64),
#         ('n_dependency_csubj', Float64),
#         ('n_dependency_csubjpass', Float64),
#         ('n_dependency_dative', Float64),
#         ('n_dependency_dep', Float64),
#         ('n_dependency_det', Float64),
#         ('n_dependency_dobj', Float64),
#         ('n_dependency_expl', Float64),
#         ('n_dependency_intj', Float64),
#         ('n_dependency_mark', Float64),
#         ('n_dependency_meta', Float64),
#         ('n_dependency_neg', Float64),
#         ('n_dependency_nounmod', Float64),
#         ('n_dependency_npmod', Float64),
#         ('n_dependency_nsubj', Float64),
#         ('n_dependency_nsubjpass', Float64),
#         ('n_dependency_nummod', Float64),
#         ('n_dependency_oprd', Float64),
#         ('n_dependency_parataxis', Float64),
#         ('n_dependency_pcomp', Float64),
#         ('n_dependency_pobj', Float64),
#         ('n_dependency_poss', Float64),
#         ('n_dependency_preconj', Float64),
#         ('n_dependency_predet', Float64),
#         ('n_dependency_prep', Float64),
#         ('n_dependency_prt', Float64),
#         ('n_dependency_punct', Float64),
#         ('n_dependency_quantmod', Float64),
#         ('n_dependency_relcl', Float64),
#         ('n_dependency_root', Float64),
#         ('n_dependency_xcomp', Float64),
#         ('avg_concreteness', Float64),
#         ('n_high_concreteness', Float64),
#         ('n_low_concreteness', Float64),
#         ('avg_sd_concreteness', Float64),
#         ('n_controversial_concreteness', Float64),
#         ('avg_aoa', Float64),
#         ('n_high_aoa', Float64),
#         ('n_low_aoa', Float64),
#         ('avg_sd_aoa', Float64),
#         ('n_controversial_aoa', Float64),
#         ('avg_prevalence', Float64),
#         ('n_high_prevalence', Float64),
#         ('n_low_prevalence', Float64),
#         ('avg_socialness', Float64),
#         ('n_high_socialness', Float64),
#         ('n_low_socialness', Float64),
#         ('avg_sd_socialness', Float64),
#         ('n_controversial_socialness', Float64),
#         ('avg_iconicity', Float64),
#         ('n_high_iconicity', Float64),
#         ('n_low_iconicity', Float64),
#         ('avg_sd_iconicity', Float64),
#         ('n_controversial_iconicity', Float64),
#         ('avg_Auditory_sensorimotor', Float64),
#         ('avg_Gustatory_sensorimotor', Float64),
#         ('avg_Haptic_sensorimotor', Float64),
#         ('avg_Interoceptive_sensorimotor', Float64),
#         ('avg_Olfactory_sensorimotor', Float64),
#         ('avg_Visual_sensorimotor', Float64),
#         ('avg_Foot_leg_sensorimotor', Float64),
#         ('avg_Hand_arm_sensorimotor', Float64),
#         ('avg_Head_sensorimotor', Float64),
#         ('avg_Mouth_sensorimotor', Float64),
#         ('avg_Torso_sensorimotor', Float64),
#         ('n_high_Auditory_sensorimotor', Float64),
#         ('n_high_Gustatory_sensorimotor', Float64),
#         ('n_high_Haptic_sensorimotor', Float64),
#         ('n_high_Interoceptive_sensorimotor', Float64),
#         ('n_high_Olfactory_sensorimotor', Float64),
#         ('n_high_Visual_sensorimotor', Float64),
#         ('n_high_Foot_leg_sensorimotor', Float64),
#         ('n_high_Hand_arm_sensorimotor', Float64),
#         ('n_high_Head_sensorimotor', Float64),
#         ('n_high_Mouth_sensorimotor', Float64),
#         ('n_high_Torso_sensorimotor', Float64),
#         ('n_low_Auditory_sensorimotor', Float64),
#         ('n_low_Gustatory_sensorimotor', Float64),
#         ('n_low_Haptic_sensorimotor', Float64),
#         ('n_low_Interoceptive_sensorimotor', Float64),
#         ('n_low_Olfactory_sensorimotor', Float64),
#         ('n_low_Visual_sensorimotor', Float64),
#         ('n_low_Foot_leg_sensorimotor', Float64),
#         ('n_low_Hand_arm_sensorimotor', Float64),
#         ('n_low_Head_sensorimotor', Float64),
#         ('n_low_Mouth_sensorimotor', Float64),
#         ('n_low_Torso_sensorimotor', Float64),
#         ('avg_sd_Auditory_sensorimotor', Float64),
#         ('avg_sd_Gustatory_sensorimotor', Float64),
#         ('avg_sd_Haptic_sensorimotor', Float64),
#         ('avg_sd_Interoceptive_sensorimotor', Float64),
#         ('avg_sd_Olfactory_sensorimotor', Float64),
#         ('avg_sd_Visual_sensorimotor', Float64),
#         ('avg_sd_Foot_leg_sensorimotor', Float64),
#         ('avg_sd_Hand_arm_sensorimotor', Float64),
#         ('avg_sd_Head_sensorimotor', Float64),
#         ('avg_sd_Mouth_sensorimotor', Float64),
#         ('avg_sd_Torso_sensorimotor', Float64),
#         ('n_controversial_Auditory_sensorimotor', Float64),
#         ('n_controversial_Gustatory_sensorimotor', Float64),
#         ('n_controversial_Haptic_sensorimotor', Float64),
#         ('n_controversial_Interoceptive_sensorimotor', Float64),
#         ('n_controversial_Olfactory_sensorimotor', Float64),
#         ('n_controversial_Visual_sensorimotor', Float64),
#         ('n_controversial_Foot_leg_sensorimotor', Float64),
#         ('n_controversial_Hand_arm_sensorimotor', Float64),
#         ('n_controversial_Head_sensorimotor', Float64),
#         ('n_controversial_Mouth_sensorimotor', Float64),
#         ('n_controversial_Torso_sensorimotor', Float64),
#         ('n_VERB_VerbForm_Conf', Float64),
#         ('n_VERB_VerbForm_Fin', Float64),
#         ('n_VERB_VerbForm_Gdv', Float64),
#         ('n_VERB_VerbForm_Ger', Float64),
#         ('n_VERB_VerbForm_Inf', Float64),
#         ('n_VERB_VerbForm_Part', Float64),
#         ('n_VERB_VerbForm_Sup', Float64),
#         ('n_VERB_VerbForm_Vnoun', Float64),
#         ('n_VERB_Mood_Adm', Float64),
#         ('n_VERB_Mood_Cnd', Float64),
#         ('n_VERB_Mood_Des', Float64),
#         ('n_VERB_Mood_Imp', Float64),
#         ('n_VERB_Mood_Ind', Float64),
#         ('n_VERB_Mood_Irr', Float64),
#         ('n_VERB_Mood_Jus', Float64),
#         ('n_VERB_Mood_Nec', Float64),
#         ('n_VERB_Mood_Opt', Float64),
#         ('n_VERB_Mood_Pot', Float64),
#         ('n_VERB_Mood_Prp', Float64),
#         ('n_VERB_Mood_Qot', Float64),
#         ('n_VERB_Mood_Sub', Float64),
#         ('n_VERB_Tense_Fut', Float64),
#         ('n_VERB_Tense_Imp', Float64),
#         ('n_VERB_Tense_Past', Float64),
#         ('n_VERB_Tense_Pres', Float64),
#         ('n_VERB_Tense_Pqp', Float64),
#         ('n_VERB_Aspect_Hab', Float64),
#         ('n_VERB_Aspect_Imp', Float64),
#         ('n_VERB_Aspect_Iter', Float64),
#         ('n_VERB_Aspect_Perf', Float64),
#         ('n_VERB_Aspect_Prog', Float64),
#         ('n_VERB_Aspect_Prosp', Float64),
#         ('n_VERB_Voice_Act', Float64),
#         ('n_VERB_Voice_Antip', Float64),
#         ('n_VERB_Voice_Bfoc', Float64),
#         ('n_VERB_Voice_Cau', Float64),
#         ('n_VERB_Voice_Dir', Float64),
#         ('n_VERB_Voice_Inv', Float64),
#         ('n_VERB_Voice_Lfoc', Float64),
#         ('n_VERB_Voice_Mid', Float64),
#         ('n_VERB_Voice_Pass', Float64),
#         ('n_VERB_Voice_Rcp', Float64),
#         ('n_VERB_Evident_Fh', Float64),
#         ('n_VERB_Evident_Nfh', Float64),
#         ('n_VERB_Polarity_Neg', Float64),
#         ('n_VERB_Polarity_Pos', Float64),
#         ('n_VERB_Person_0', Float64),
#         ('n_VERB_Person_1', Float64),
#         ('n_VERB_Person_2', Float64),
#         ('n_VERB_Person_3', Float64),
#         ('n_VERB_Person_4', Float64),
#         ('n_VERB_Polite_Elev', Float64),
#         ('n_VERB_Polite_Form', Float64),
#         ('n_VERB_Polite_Humb', Float64),
#         ('n_VERB_Polite_Infm', Float64),
#         ('n_VERB_Clusivity_Ex', Float64),
#         ('n_VERB_Clusivity_In', Float64),
#         ('n_VERB_Gender_Com', Float64),
#         ('n_VERB_Gender_Fem', Float64),
#         ('n_VERB_Gender_Masc', Float64),
#         ('n_VERB_Gender_Neut', Float64),
#         ('n_VERB_Animacy_Anim', Float64),
#         ('n_VERB_Animacy_Hum', Float64),
#         ('n_VERB_Animacy_Inan', Float64),
#         ('n_VERB_Animacy_Nhum', Float64),
#         ('n_VERB_Number_Coll', Float64),
#         ('n_VERB_Number_Count', Float64),
#         ('n_VERB_Number_Dual', Float64),
#         ('n_VERB_Number_Grpa', Float64),
#         ('n_VERB_Number_Grpl', Float64),
#         ('n_VERB_Number_Inv', Float64),
#         ('n_VERB_Number_Pauc', Float64),
#         ('n_VERB_Number_Plur', Float64),
#         ('n_VERB_Number_Ptan', Float64),
#         ('n_VERB_Number_Sing', Float64),
#         ('n_VERB_Number_Tri', Float64),
#         ('n_VERB_Case_Abs', Float64),
#         ('n_VERB_Case_Acc', Float64),
#         ('n_VERB_Case_Erg', Float64),
#         ('n_VERB_Case_Nom', Float64),
#         ('n_VERB_Case_Abe', Float64),
#         ('n_VERB_Case_Ben', Float64),
#         ('n_VERB_Case_Cau', Float64),
#         ('n_VERB_Case_Cmp', Float64),
#         ('n_VERB_Case_Cns', Float64),
#         ('n_VERB_Case_Com', Float64),
#         ('n_VERB_Case_Dat', Float64),
#         ('n_VERB_Case_Dis', Float64),
#         ('n_VERB_Case_Equ', Float64),
#         ('n_VERB_Case_Gen', Float64),
#         ('n_VERB_Case_Ins', Float64),
#         ('n_VERB_Case_Par', Float64),
#         ('n_VERB_Case_Tem', Float64),
#         ('n_VERB_Case_Tra', Float64),
#         ('n_VERB_Case_Voc', Float64),
#         ('n_VERB_Case_Abl', Float64),
#         ('n_VERB_Case_Add', Float64),
#         ('n_VERB_Case_Ade', Float64),
#         ('n_VERB_Case_All', Float64),
#         ('n_VERB_Case_Del', Float64),
#         ('n_VERB_Case_Ela', Float64),
#         ('n_VERB_Case_Ill', Float64),
#         ('n_VERB_Case_Ine', Float64),
#         ('n_VERB_Case_Lat', Float64),
#         ('n_VERB_Case_Loc', Float64),
#         ('n_VERB_Case_Per', Float64),
#         ('n_VERB_Case_Sbe', Float64),
#         ('n_VERB_Case_Sub', Float64),
#         ('n_VERB_Case_Sup', Float64),
#         ('n_VERB_Case_Ter', Float64),
#         ('n_VERB_Abbr_Yes', Float64),
#         ('n_VERB_Foreign_Yes', Float64),
#         ('n_NOUN_Gender_Com', Float64),
#         ('n_NOUN_Gender_Fem', Float64),
#         ('n_NOUN_Gender_Masc', Float64),
#         ('n_NOUN_Gender_Neut', Float64),
#         ('n_NOUN_Animacy_Anim', Float64),
#         ('n_NOUN_Animacy_Hum', Float64),
#         ('n_NOUN_Animacy_Inan', Float64),
#         ('n_NOUN_Animacy_Nhum', Float64),
#         ('n_NOUN_Number_Coll', Float64),
#         ('n_NOUN_Number_Count', Float64),
#         ('n_NOUN_Number_Dual', Float64),
#         ('n_NOUN_Number_Grpa', Float64),
#         ('n_NOUN_Number_Grpl', Float64),
#         ('n_NOUN_Number_Inv', Float64),
#         ('n_NOUN_Number_Pauc', Float64),
#         ('n_NOUN_Number_Plur', Float64),
#         ('n_NOUN_Number_Ptan', Float64),
#         ('n_NOUN_Number_Sing', Float64),
#         ('n_NOUN_Number_Tri', Float64),
#         ('n_NOUN_Case_Abs', Float64),
#         ('n_NOUN_Case_Acc', Float64),
#         ('n_NOUN_Case_Erg', Float64),
#         ('n_NOUN_Case_Nom', Float64),
#         ('n_NOUN_Case_Abe', Float64),
#         ('n_NOUN_Case_Ben', Float64),
#         ('n_NOUN_Case_Cau', Float64),
#         ('n_NOUN_Case_Cmp', Float64),
#         ('n_NOUN_Case_Cns', Float64),
#         ('n_NOUN_Case_Com', Float64),
#         ('n_NOUN_Case_Dat', Float64),
#         ('n_NOUN_Case_Dis', Float64),
#         ('n_NOUN_Case_Equ', Float64),
#         ('n_NOUN_Case_Gen', Float64),
#         ('n_NOUN_Case_Ins', Float64),
#         ('n_NOUN_Case_Par', Float64),
#         ('n_NOUN_Case_Tem', Float64),
#         ('n_NOUN_Case_Tra', Float64),
#         ('n_NOUN_Case_Voc', Float64),
#         ('n_NOUN_Case_Abl', Float64),
#         ('n_NOUN_Case_Add', Float64),
#         ('n_NOUN_Case_Ade', Float64),
#         ('n_NOUN_Case_All', Float64),
#         ('n_NOUN_Case_Del', Float64),
#         ('n_NOUN_Case_Ela', Float64),
#         ('n_NOUN_Case_Ill', Float64),
#         ('n_NOUN_Case_Ine', Float64),
#         ('n_NOUN_Case_Lat', Float64),
#         ('n_NOUN_Case_Loc', Float64),
#         ('n_NOUN_Case_Per', Float64),
#         ('n_NOUN_Case_Sbe', Float64),
#         ('n_NOUN_Case_Sub', Float64),
#         ('n_NOUN_Case_Sup', Float64),
#         ('n_NOUN_Case_Ter', Float64),
#         ('n_NOUN_Definite_Com', Float64),
#         ('n_NOUN_Definite_Cons', Float64),
#         ('n_NOUN_Definite_Def', Float64),
#         ('n_NOUN_Definite_Ind', Float64),
#         ('n_NOUN_Definite_Spec', Float64),
#         ('n_NOUN_Abbr_Yes', Float64),
#         ('n_NOUN_Degree_Abs', Float64),
#         ('n_NOUN_Degree_Aug', Float64),
#         ('n_NOUN_Degree_Cmp', Float64),
#         ('n_NOUN_Degree_Dim', Float64),
#         ('n_NOUN_Degree_Equ', Float64),
#         ('n_NOUN_Degree_Pos', Float64),
#         ('n_NOUN_Degree_Sup', Float64),
#         ('n_NOUN_Tense_Fut', Float64),
#         ('n_NOUN_Tense_Imp', Float64),
#         ('n_NOUN_Tense_Past', Float64),
#         ('n_NOUN_Tense_Pres', Float64),
#         ('n_NOUN_Tense_Pqp', Float64),
#         ('n_NOUN_Aspect_Hab', Float64),
#         ('n_NOUN_Aspect_Imp', Float64),
#         ('n_NOUN_Aspect_Iter', Float64),
#         ('n_NOUN_Aspect_Perf', Float64),
#         ('n_NOUN_Aspect_Prog', Float64),
#         ('n_NOUN_Aspect_Prosp', Float64),
#         ('n_NOUN_Voice_Act', Float64),
#         ('n_NOUN_Voice_Antip', Float64),
#         ('n_NOUN_Voice_Bfoc', Float64),
#         ('n_NOUN_Voice_Cau', Float64),
#         ('n_NOUN_Voice_Dir', Float64),
#         ('n_NOUN_Voice_Inv', Float64),
#         ('n_NOUN_Voice_Lfoc', Float64),
#         ('n_NOUN_Voice_Mid', Float64),
#         ('n_NOUN_Voice_Pass', Float64),
#         ('n_NOUN_Voice_Rcp', Float64),
#         ('n_NOUN_Polarity_Neg', Float64),
#         ('n_NOUN_Polarity_Pos', Float64),
#         ('n_NOUN_Foreign_Yes', Float64),
#         ('n_PRON_PronType_Art', Float64),
#         ('n_PRON_PronType_Dem', Float64),
#         ('n_PRON_PronType_Emp', Float64),
#         ('n_PRON_PronType_Exc', Float64),
#         ('n_PRON_PronType_Ind', Float64),
#         ('n_PRON_PronType_Int', Float64),
#         ('n_PRON_PronType_Neg', Float64),
#         ('n_PRON_PronType_Prs', Float64),
#         ('n_PRON_PronType_Rcp', Float64),
#         ('n_PRON_PronType_Rel', Float64),
#         ('n_PRON_PronType_Tot', Float64),
#         ('n_PRON_Poss_Yes', Float64),
#         ('n_PRON_Reflex_Yes', Float64),
#         ('n_PRON_Gender_Com', Float64),
#         ('n_PRON_Gender_Fem', Float64),
#         ('n_PRON_Gender_Masc', Float64),
#         ('n_PRON_Gender_Neut', Float64),
#         ('n_PRON_Animacy_Anim', Float64),
#         ('n_PRON_Animacy_Hum', Float64),
#         ('n_PRON_Animacy_Inan', Float64),
#         ('n_PRON_Animacy_Nhum', Float64),
#         ('n_PRON_Aspect_Hab', Float64),
#         ('n_PRON_Aspect_Imp', Float64),
#         ('n_PRON_Aspect_Iter', Float64),
#         ('n_PRON_Aspect_Perf', Float64),
#         ('n_PRON_Aspect_Prog', Float64),
#         ('n_PRON_Aspect_Prosp', Float64),
#         ('n_PRON_Tense_Fut', Float64),
#         ('n_PRON_Tense_Imp', Float64),
#         ('n_PRON_Tense_Past', Float64),
#         ('n_PRON_Tense_Pres', Float64),
#         ('n_PRON_Tense_Pqp', Float64),
#         ('n_PRON_Voice_Act', Float64),
#         ('n_PRON_Voice_Antip', Float64),
#         ('n_PRON_Voice_Bfoc', Float64),
#         ('n_PRON_Voice_Cau', Float64),
#         ('n_PRON_Voice_Dir', Float64),
#         ('n_PRON_Voice_Inv', Float64),
#         ('n_PRON_Voice_Lfoc', Float64),
#         ('n_PRON_Voice_Mid', Float64),
#         ('n_PRON_Voice_Pass', Float64),
#         ('n_PRON_Voice_Rcp', Float64),
#         ('n_PRON_Polarity_Neg', Float64),
#         ('n_PRON_Polarity_Pos', Float64),
#         ('n_PRON_Number_Coll', Float64),
#         ('n_PRON_Number_Count', Float64),
#         ('n_PRON_Number_Dual', Float64),
#         ('n_PRON_Number_Grpa', Float64),
#         ('n_PRON_Number_Grpl', Float64),
#         ('n_PRON_Number_Inv', Float64),
#         ('n_PRON_Number_Pauc', Float64),
#         ('n_PRON_Number_Plur', Float64),
#         ('n_PRON_Number_Ptan', Float64),
#         ('n_PRON_Number_Sing', Float64),
#         ('n_PRON_Number_Tri', Float64),
#         ('n_PRON_Case_Abs', Float64),
#         ('n_PRON_Case_Acc', Float64),
#         ('n_PRON_Case_Erg', Float64),
#         ('n_PRON_Case_Nom', Float64),
#         ('n_PRON_Case_Abe', Float64),
#         ('n_PRON_Case_Ben', Float64),
#         ('n_PRON_Case_Cau', Float64),
#         ('n_PRON_Case_Cmp', Float64),
#         ('n_PRON_Case_Cns', Float64),
#         ('n_PRON_Case_Com', Float64),
#         ('n_PRON_Case_Dat', Float64),
#         ('n_PRON_Case_Dis', Float64),
#         ('n_PRON_Case_Equ', Float64),
#         ('n_PRON_Case_Gen', Float64),
#         ('n_PRON_Case_Ins', Float64),
#         ('n_PRON_Case_Par', Float64),
#         ('n_PRON_Case_Tem', Float64),
#         ('n_PRON_Case_Tra', Float64),
#         ('n_PRON_Case_Voc', Float64),
#         ('n_PRON_Case_Abl', Float64),
#         ('n_PRON_Case_Add', Float64),
#         ('n_PRON_Case_Ade', Float64),
#         ('n_PRON_Case_All', Float64),
#         ('n_PRON_Case_Del', Float64),
#         ('n_PRON_Case_Ela', Float64),
#         ('n_PRON_Case_Ill', Float64),
#         ('n_PRON_Case_Ine', Float64),
#         ('n_PRON_Case_Lat', Float64),
#         ('n_PRON_Case_Loc', Float64),
#         ('n_PRON_Case_Per', Float64),
#         ('n_PRON_Case_Sbe', Float64),
#         ('n_PRON_Case_Sub', Float64),
#         ('n_PRON_Case_Sup', Float64),
#         ('n_PRON_Case_Ter', Float64),
#         ('n_PRON_Deixis_Abv', Float64),
#         ('n_PRON_Deixis_Bel', Float64),
#         ('n_PRON_Deixis_Even', Float64),
#         ('n_PRON_Deixis_Med', Float64),
#         ('n_PRON_Deixis_Nvis', Float64),
#         ('n_PRON_Deixis_Prox', Float64),
#         ('n_PRON_Deixis_Remt', Float64),
#         ('n_PRON_DeixisRef_0', Float64),
#         ('n_PRON_DeixisRef_1', Float64),
#         ('n_PRON_Person_0', Float64),
#         ('n_PRON_Person_1', Float64),
#         ('n_PRON_Person_2', Float64),
#         ('n_PRON_Person_3', Float64),
#         ('n_PRON_Person_4', Float64),
#         ('n_PRON_Clusivity_Ex', Float64),
#         ('n_PRON_Clusivity_In', Float64),
#         ('n_PRON_Abbr_Yes', Float64),
#         ('n_PRON_Foreign_Yes', Float64),
#         ('n_ADJ_Gender_Com', Float64),
#         ('n_ADJ_Gender_Fem', Float64),
#         ('n_ADJ_Gender_Masc', Float64),
#         ('n_ADJ_Gender_Neut', Float64),
#         ('n_ADJ_Animacy_Anim', Float64),
#         ('n_ADJ_Animacy_Hum', Float64),
#         ('n_ADJ_Animacy_Inan', Float64),
#         ('n_ADJ_Animacy_Nhum', Float64),
#         ('n_ADJ_Number_Coll', Float64),
#         ('n_ADJ_Number_Count', Float64),
#         ('n_ADJ_Number_Dual', Float64),
#         ('n_ADJ_Number_Grpa', Float64),
#         ('n_ADJ_Number_Grpl', Float64),
#         ('n_ADJ_Number_Inv', Float64),
#         ('n_ADJ_Number_Pauc', Float64),
#         ('n_ADJ_Number_Plur', Float64),
#         ('n_ADJ_Number_Ptan', Float64),
#         ('n_ADJ_Number_Sing', Float64),
#         ('n_ADJ_Number_Tri', Float64),
#         ('n_ADJ_Case_Abs', Float64),
#         ('n_ADJ_Case_Acc', Float64),
#         ('n_ADJ_Case_Erg', Float64),
#         ('n_ADJ_Case_Nom', Float64),
#         ('n_ADJ_Case_Abe', Float64),
#         ('n_ADJ_Case_Ben', Float64),
#         ('n_ADJ_Case_Cau', Float64),
#         ('n_ADJ_Case_Cmp', Float64),
#         ('n_ADJ_Case_Cns', Float64),
#         ('n_ADJ_Case_Com', Float64),
#         ('n_ADJ_Case_Dat', Float64),
#         ('n_ADJ_Case_Dis', Float64),
#         ('n_ADJ_Case_Equ', Float64),
#         ('n_ADJ_Case_Gen', Float64),
#         ('n_ADJ_Case_Ins', Float64),
#         ('n_ADJ_Case_Par', Float64),
#         ('n_ADJ_Case_Tem', Float64),
#         ('n_ADJ_Case_Tra', Float64),
#         ('n_ADJ_Case_Voc', Float64),
#         ('n_ADJ_Case_Abl', Float64),
#         ('n_ADJ_Case_Add', Float64),
#         ('n_ADJ_Case_Ade', Float64),
#         ('n_ADJ_Case_All', Float64),
#         ('n_ADJ_Case_Del', Float64),
#         ('n_ADJ_Case_Ela', Float64),
#         ('n_ADJ_Case_Ill', Float64),
#         ('n_ADJ_Case_Ine', Float64),
#         ('n_ADJ_Case_Lat', Float64),
#         ('n_ADJ_Case_Loc', Float64),
#         ('n_ADJ_Case_Per', Float64),
#         ('n_ADJ_Case_Sbe', Float64),
#         ('n_ADJ_Case_Sub', Float64),
#         ('n_ADJ_Case_Sup', Float64),
#         ('n_ADJ_Case_Ter', Float64),
#         ('n_ADJ_Definite_Com', Float64),
#         ('n_ADJ_Definite_Cons', Float64),
#         ('n_ADJ_Definite_Def', Float64),
#         ('n_ADJ_Definite_Ind', Float64),
#         ('n_ADJ_Definite_Spec', Float64),
#         ('n_ADJ_Degree_Abs', Float64),
#         ('n_ADJ_Degree_Aug', Float64),
#         ('n_ADJ_Degree_Cmp', Float64),
#         ('n_ADJ_Degree_Dim', Float64),
#         ('n_ADJ_Degree_Equ', Float64),
#         ('n_ADJ_Degree_Pos', Float64),
#         ('n_ADJ_Degree_Sup', Float64),
#         ('n_ADJ_Ten_Fut', Float64),
#         ('n_ADJ_Ten_Imp', Float64),
#         ('n_ADJ_Ten_Past', Float64),
#         ('n_ADJ_Ten_Pres', Float64),
#         ('n_ADJ_Ten_Pqp', Float64),
#         ('n_ADJ_Aspect_Hab', Float64),
#         ('n_ADJ_Aspect_Imp', Float64),
#         ('n_ADJ_Aspect_Iter', Float64),
#         ('n_ADJ_Aspect_Perf', Float64),
#         ('n_ADJ_Aspect_Prog', Float64),
#         ('n_ADJ_Aspect_Prosp', Float64),
#         ('n_ADJ_Voice_Act', Float64),
#         ('n_ADJ_Voice_Antip', Float64),
#         ('n_ADJ_Voice_Bfoc', Float64),
#         ('n_ADJ_Voice_Cau', Float64),
#         ('n_ADJ_Voice_Dir', Float64),
#         ('n_ADJ_Voice_Inv', Float64),
#         ('n_ADJ_Voice_Lfoc', Float64),
#         ('n_ADJ_Voice_Mid', Float64),
#         ('n_ADJ_Voice_Pass', Float64),
#         ('n_ADJ_Voice_Rcp', Float64),
#         ('n_ADJ_Polarity_Neg', Float64),
#         ('n_ADJ_Polarity_Pos', Float64),
#         ('n_ADJ_Abbr_Yes', Float64),
#         ('n_ADJ_Foreign_Yes', Float64),
#         ('n_DET_Gender_Com', Float64),
#         ('n_DET_Gender_Fem', Float64),
#         ('n_DET_Gender_Masc', Float64),
#         ('n_DET_Gender_Neut', Float64),
#         ('n_DET_Animacy_Anim', Float64),
#         ('n_DET_Animacy_Hum', Float64),
#         ('n_DET_Animacy_Inan', Float64),
#         ('n_DET_Animacy_Nhum', Float64),
#         ('n_DET_Number_Coll', Float64),
#         ('n_DET_Number_Count', Float64),
#         ('n_DET_Number_Dual', Float64),
#         ('n_DET_Number_Grpa', Float64),
#         ('n_DET_Number_Grpl', Float64),
#         ('n_DET_Number_Inv', Float64),
#         ('n_DET_Number_Pauc', Float64),
#         ('n_DET_Number_Plur', Float64),
#         ('n_DET_Number_Ptan', Float64),
#         ('n_DET_Number_Sing', Float64),
#         ('n_DET_Number_Tri', Float64),
#         ('n_DET_Case_Abs', Float64),
#         ('n_DET_Case_Acc', Float64),
#         ('n_DET_Case_Erg', Float64),
#         ('n_DET_Case_Nom', Float64),
#         ('n_DET_Case_Abe', Float64),
#         ('n_DET_Case_Ben', Float64),
#         ('n_DET_Case_Cau', Float64),
#         ('n_DET_Case_Cmp', Float64),
#         ('n_DET_Case_Cns', Float64),
#         ('n_DET_Case_Com', Float64),
#         ('n_DET_Case_Dat', Float64),
#         ('n_DET_Case_Dis', Float64),
#         ('n_DET_Case_Equ', Float64),
#         ('n_DET_Case_Gen', Float64),
#         ('n_DET_Case_Ins', Float64),
#         ('n_DET_Case_Par', Float64),
#         ('n_DET_Case_Tem', Float64),
#         ('n_DET_Case_Tra', Float64),
#         ('n_DET_Case_Voc', Float64),
#         ('n_DET_Case_Abl', Float64),
#         ('n_DET_Case_Add', Float64),
#         ('n_DET_Case_Ade', Float64),
#         ('n_DET_Case_All', Float64),
#         ('n_DET_Case_Del', Float64),
#         ('n_DET_Case_Ela', Float64),
#         ('n_DET_Case_Ill', Float64),
#         ('n_DET_Case_Ine', Float64),
#         ('n_DET_Case_Lat', Float64),
#         ('n_DET_Case_Loc', Float64),
#         ('n_DET_Case_Per', Float64),
#         ('n_DET_Case_Sbe', Float64),
#         ('n_DET_Case_Sub', Float64),
#         ('n_DET_Case_Sup', Float64),
#         ('n_DET_Case_Ter', Float64),
#         ('n_DET_Definite_Com', Float64),
#         ('n_DET_Definite_Cons', Float64),
#         ('n_DET_Definite_Def', Float64),
#         ('n_DET_Definite_Ind', Float64),
#         ('n_DET_Definite_Spec', Float64),
#         ('n_DET_Deixis_Abv', Float64),
#         ('n_DET_Deixis_Bel', Float64),
#         ('n_DET_Deixis_Even', Float64),
#         ('n_DET_Deixis_Med', Float64),
#         ('n_DET_Deixis_Nvis', Float64),
#         ('n_DET_Deixis_Prox', Float64),
#         ('n_DET_Deixis_Remt', Float64),
#         ('n_DET_DeixisRef_0', Float64),
#         ('n_DET_DeixisRef_1', Float64),
#         ('n_DET_Person_0', Float64),
#         ('n_DET_Person_1', Float64),
#         ('n_DET_Person_2', Float64),
#         ('n_DET_Person_3', Float64),
#         ('n_DET_Person_4', Float64),
#         ('n_DET_Abbr_Yes', Float64),
#         ('n_DET_Foreign_Yes', Float64),
#         ('n_NUM_NumType_Card', Float64),
#         ('n_NUM_NumType_Dist', Float64),
#         ('n_NUM_NumType_Frac', Float64),
#         ('n_NUM_NumType_Mult', Float64),
#         ('n_NUM_NumType_Ord', Float64),
#         ('n_NUM_NumType_Range', Float64),
#         ('n_NUM_NumType_Sets', Float64),
#         ('n_NUM_NumForm_Digit', Float64),
#         ('n_NUM_NumForm_Combi', Float64),
#         ('n_NUM_NumForm_Word', Float64),
#         ('n_NUM_NumForm_Roman', Float64),
#         ('n_NUM_Gender_Com', Float64),
#         ('n_NUM_Gender_Fem', Float64),
#         ('n_NUM_Gender_Masc', Float64),
#         ('n_NUM_Gender_Neut', Float64),
#         ('n_NUM_Animacy_Anim', Float64),
#         ('n_NUM_Animacy_Hum', Float64),
#         ('n_NUM_Animacy_Inan', Float64),
#         ('n_NUM_Animacy_Nhum', Float64),
#         ('n_NUM_Number_Coll', Float64),
#         ('n_NUM_Number_Count', Float64),
#         ('n_NUM_Number_Dual', Float64),
#         ('n_NUM_Number_Grpa', Float64),
#         ('n_NUM_Number_Grpl', Float64),
#         ('n_NUM_Number_Inv', Float64),
#         ('n_NUM_Number_Pauc', Float64),
#         ('n_NUM_Number_Plur', Float64),
#         ('n_NUM_Number_Ptan', Float64),
#         ('n_NUM_Number_Sing', Float64),
#         ('n_NUM_Number_Tri', Float64),
#         ('n_NUM_Case_Abs', Float64),
#         ('n_NUM_Case_Acc', Float64),
#         ('n_NUM_Case_Erg', Float64),
#         ('n_NUM_Case_Nom', Float64),
#         ('n_NUM_Case_Abe', Float64),
#         ('n_NUM_Case_Ben', Float64),
#         ('n_NUM_Case_Cau', Float64),
#         ('n_NUM_Case_Cmp', Float64),
#         ('n_NUM_Case_Cns', Float64),
#         ('n_NUM_Case_Com', Float64),
#         ('n_NUM_Case_Dat', Float64),
#         ('n_NUM_Case_Dis', Float64),
#         ('n_NUM_Case_Equ', Float64),
#         ('n_NUM_Case_Gen', Float64),
#         ('n_NUM_Case_Ins', Float64),
#         ('n_NUM_Case_Par', Float64),
#         ('n_NUM_Case_Tem', Float64),
#         ('n_NUM_Case_Tra', Float64),
#         ('n_NUM_Case_Voc', Float64),
#         ('n_NUM_Case_Abl', Float64),
#         ('n_NUM_Case_Add', Float64),
#         ('n_NUM_Case_Ade', Float64),
#         ('n_NUM_Case_All', Float64),
#         ('n_NUM_Case_Del', Float64),
#         ('n_NUM_Case_Ela', Float64),
#         ('n_NUM_Case_Ill', Float64),
#         ('n_NUM_Case_Ine', Float64),
#         ('n_NUM_Case_Lat', Float64),
#         ('n_NUM_Case_Loc', Float64),
#         ('n_NUM_Case_Per', Float64),
#         ('n_NUM_Case_Sbe', Float64),
#         ('n_NUM_Case_Sub', Float64),
#         ('n_NUM_Case_Sup', Float64),
#         ('n_NUM_Case_Ter', Float64),
#         ('n_NUM_Abbr_Yes', Float64),
#         ('n_NUM_Foreign_Yes', Float64),
#         ('n_ADV_Polarity_Neg', Float64),
#         ('n_ADV_Polarity_Pos', Float64),
#         ('n_ADV_Degree_Abs', Float64),
#         ('n_ADV_Degree_Aug', Float64),
#         ('n_ADV_Degree_Cmp', Float64),
#         ('n_ADV_Degree_Dim', Float64),
#         ('n_ADV_Degree_Equ', Float64),
#         ('n_ADV_Degree_Pos', Float64),
#         ('n_ADV_Degree_Sup', Float64),
#         ('n_ADV_Abbr_Yes', Float64),
#         ('n_ADV_Foreign_Yes', Float64),
#         ('n_ADV_Deixis_Abv', Float64),
#         ('n_ADV_Deixis_Bel', Float64),
#         ('n_ADV_Deixis_Even', Float64),
#         ('n_ADV_Deixis_Med', Float64),
#         ('n_ADV_Deixis_Nvis', Float64),
#         ('n_ADV_Deixis_Prox', Float64),
#         ('n_ADV_Deixis_Remt', Float64),
#         ('n_ADV_DeixisRef_0', Float64),
#         ('n_ADV_DeixisRef_1', Float64),
#         ('n_ADV_Tense_Fut', Float64),
#         ('n_ADV_Tense_Imp', Float64),
#         ('n_ADV_Tense_Past', Float64),
#         ('n_ADV_Tense_Pres', Float64),
#         ('n_ADV_Tense_Pqp', Float64),
#         ('n_ADV_Aspect_Hab', Float64),
#         ('n_ADV_Aspect_Imp', Float64),
#         ('n_ADV_Aspect_Iter', Float64),
#         ('n_ADV_Aspect_Perf', Float64),
#         ('n_ADV_Aspect_Prog', Float64),
#         ('n_ADV_Aspect_Prosp', Float64),
#         ('n_ADV_Voice_Act', Float64),
#         ('n_ADV_Voice_Antip', Float64),
#         ('n_ADV_Voice_Bfoc', Float64),
#         ('n_ADV_Voice_Cau', Float64),
#         ('n_ADV_Voice_Dir', Float64),
#         ('n_ADV_Voice_Inv', Float64),
#         ('n_ADV_Voice_Lfoc', Float64),
#         ('n_ADV_Voice_Mid', Float64),
#         ('n_ADV_Voice_Pass', Float64),
#         ('n_ADV_Voice_Rcp', Float64),
#         ('n_PROPN_Gender_Com', Float64),
#         ('n_PROPN_Gender_Fem', Float64),
#         ('n_PROPN_Gender_Masc', Float64),
#         ('n_PROPN_Gender_Neut', Float64),
#         ('n_PROPN_Animacy_Anim', Float64),
#         ('n_PROPN_Animacy_Hum', Float64),
#         ('n_PROPN_Animacy_Inan', Float64),
#         ('n_PROPN_Animacy_Nhum', Float64),
#         ('n_PROPN_Number_Coll', Float64),
#         ('n_PROPN_Number_Count', Float64),
#         ('n_PROPN_Number_Dual', Float64),
#         ('n_PROPN_Number_Grpa', Float64),
#         ('n_PROPN_Number_Grpl', Float64),
#         ('n_PROPN_Number_Inv', Float64),
#         ('n_PROPN_Number_Pauc', Float64),
#         ('n_PROPN_Number_Plur', Float64),
#         ('n_PROPN_Number_Ptan', Float64),
#         ('n_PROPN_Number_Sing', Float64),
#         ('n_PROPN_Number_Tri', Float64),
#         ('n_PROPN_Case_Abs', Float64),
#         ('n_PROPN_Case_Acc', Float64),
#         ('n_PROPN_Case_Erg', Float64),
#         ('n_PROPN_Case_Nom', Float64),
#         ('n_PROPN_Case_Abe', Float64),
#         ('n_PROPN_Case_Ben', Float64),
#         ('n_PROPN_Case_Cau', Float64),
#         ('n_PROPN_Case_Cmp', Float64),
#         ('n_PROPN_Case_Cns', Float64),
#         ('n_PROPN_Case_Com', Float64),
#         ('n_PROPN_Case_Dat', Float64),
#         ('n_PROPN_Case_Dis', Float64),
#         ('n_PROPN_Case_Equ', Float64),
#         ('n_PROPN_Case_Gen', Float64),
#         ('n_PROPN_Case_Ins', Float64),
#         ('n_PROPN_Case_Par', Float64),
#         ('n_PROPN_Case_Tem', Float64),
#         ('n_PROPN_Case_Tra', Float64),
#         ('n_PROPN_Case_Voc', Float64),
#         ('n_PROPN_Case_Abl', Float64),
#         ('n_PROPN_Case_Add', Float64),
#         ('n_PROPN_Case_Ade', Float64),
#         ('n_PROPN_Case_All', Float64),
#         ('n_PROPN_Case_Del', Float64),
#         ('n_PROPN_Case_Ela', Float64),
#         ('n_PROPN_Case_Ill', Float64),
#         ('n_PROPN_Case_Ine', Float64),
#         ('n_PROPN_Case_Lat', Float64),
#         ('n_PROPN_Case_Loc', Float64),
#         ('n_PROPN_Case_Per', Float64),
#         ('n_PROPN_Case_Sbe', Float64),
#         ('n_PROPN_Case_Sub', Float64),
#         ('n_PROPN_Case_Sup', Float64),
#         ('n_PROPN_Case_Ter', Float64),
#         ('n_PROPN_Definite_Com', Float64),
#         ('n_PROPN_Definite_Cons', Float64),
#         ('n_PROPN_Definite_Def', Float64),
#         ('n_PROPN_Definite_Ind', Float64),
#         ('n_PROPN_Definite_Spec', Float64),
#         ('n_PROPN_Degree_Abs', Float64),
#         ('n_PROPN_Degree_Aug', Float64),
#         ('n_PROPN_Degree_Cmp', Float64),
#         ('n_PROPN_Degree_Dim', Float64),
#         ('n_PROPN_Degree_Equ', Float64),
#         ('n_PROPN_Degree_Pos', Float64),
#         ('n_PROPN_Degree_Sup', Float64),
#         ('n_PROPN_Tense_Fut', Float64),
#         ('n_PROPN_Tense_Imp', Float64),
#         ('n_PROPN_Tense_Past', Float64),
#         ('n_PROPN_Tense_Pres', Float64),
#         ('n_PROPN_Tense_Pqp', Float64),
#         ('n_PROPN_Aspect_Hab', Float64),
#         ('n_PROPN_Aspect_Imp', Float64),
#         ('n_PROPN_Aspect_Iter', Float64),
#         ('n_PROPN_Aspect_Perf', Float64),
#         ('n_PROPN_Aspect_Prog', Float64),
#         ('n_PROPN_Aspect_Prosp', Float64),
#         ('n_PROPN_Voice_Act', Float64),
#         ('n_PROPN_Voice_Antip', Float64),
#         ('n_PROPN_Voice_Bfoc', Float64),
#         ('n_PROPN_Voice_Cau', Float64),
#         ('n_PROPN_Voice_Dir', Float64),
#         ('n_PROPN_Voice_Inv', Float64),
#         ('n_PROPN_Voice_Lfoc', Float64),
#         ('n_PROPN_Voice_Mid', Float64),
#         ('n_PROPN_Voice_Pass', Float64),
#         ('n_PROPN_Voice_Rcp', Float64),
#         ('n_PROPN_Polarity_Neg', Float64),
#         ('n_PROPN_Polarity_Pos', Float64),
#         ('n_PROPN_Abbr_Yes', Float64),
#         ('n_PROPN_Foreign_Yes', Float64),
#         ('n_Aux_VerbForm_Fin', Float64),
#         ('n_Aux_VerbForm_Inf', Float64),
#         ('n_Aux_VerbForm_Part', Float64),
#         ('n_Aux_Tense_Fut', Float64),
#         ('n_Aux_Tense_Imp', Float64),
#         ('n_Aux_Tense_Past', Float64),
#         ('n_Aux_Tense_Pres', Float64),
#         ('n_Aux_Tense_Pqp', Float64),
#         ('n_Aux_Aspect_Hab', Float64),
#         ('n_Aux_Aspect_Imp', Float64),
#         ('n_Aux_Aspect_Iter', Float64),
#         ('n_Aux_Aspect_Perf', Float64),
#         ('n_Aux_Aspect_Prog', Float64),
#         ('n_Aux_Aspect_Prosp', Float64),
#         ('n_Aux_Voice_Act', Float64),
#         ('n_Aux_Voice_Antip', Float64),
#         ('n_Aux_Voice_Bfoc', Float64),
#         ('n_Aux_Voice_Cau', Float64),
#         ('n_Aux_Voice_Dir', Float64),
#         ('n_Aux_Voice_Inv', Float64),
#         ('n_Aux_Voice_Lfoc', Float64),
#         ('n_Aux_Voice_Mid', Float64),
#         ('n_Aux_Voice_Pass', Float64),
#         ('n_Aux_Voice_Rcp', Float64),
#         ('n_Aux_Evident_Fh', Float64),
#         ('n_Aux_Evident_Nfh', Float64),
#         ('n_Aux_Polarity_Neg', Float64),
#         ('n_Aux_Polarity_Pos', Float64),
#         ('n_Aux_Person_0', Float64),
#         ('n_Aux_Person_1', Float64),
#         ('n_Aux_Person_2', Float64),
#         ('n_Aux_Person_3', Float64),
#         ('n_Aux_Person_4', Float64),
#         ('n_Aux_Clusivity_Ex', Float64),
#         ('n_Aux_Clusivity_In', Float64),
#         ('n_Aux_Mood_Adm', Float64),
#         ('n_Aux_Mood_Cnd', Float64),
#         ('n_Aux_Mood_Des', Float64),
#         ('n_Aux_Mood_Imp', Float64),
#         ('n_Aux_Mood_Ind', Float64),
#         ('n_Aux_Mood_Irr', Float64),
#         ('n_Aux_Mood_Jus', Float64),
#         ('n_Aux_Mood_Nec', Float64),
#         ('n_Aux_Mood_Opt', Float64),
#         ('n_Aux_Mood_Pot', Float64),
#         ('n_Aux_Mood_Prp', Float64),
#         ('n_Aux_Mood_Qot', Float64),
#         ('n_Aux_Mood_Sub', Float64),
#         ('n_Aux_Polite_Elev', Float64),
#         ...])

# %%
# this package has an issue to export the data in csv format, my solution is to convert it to pandas format first
df_pandas  = extractor.data.to_pandas()

# %%
# save our extracted features in a new csv file
df_pandas.to_csv("full_features.csv", index=False)

# %%
df_pandas
# Out:
#                                                   text  \
# 0    Slowly and gradually, all facets of their live...
# 1    What a wonderful day we had. We ventured to Si...
# 2    This text will discuss the key variations betw...
# 3    It was a day of sightseeing for us!. We saw se...
# 4    it behoves on us all to make a drastic and pro...
# ..                                                 ...
# 195    technology in schools is for everyone  The A...
# 196  I dunno. Sometimes I just think I'm doing too ...
# 197  As intelligent as I am, I overlooked a key set...
# 198  Todae, Sundae nite.... again mus think of tml....
# 199  I thought this whole having kids thingy was a ...
#
#                                    id   label      data  is_attention_check  \
# 0    5febe40a7f4bf6f477af654d3eea9ab3    male  PAN13-EN               False
# 1                             4168492       1      BLOG               False
# 2    28c118646abaf08b33535fad28820db0    male  PAN13-EN               False
# 3                              2036_3  Female    PASTEL               False
# 4    8b794cc8b9857b8704d9dc4eb5d0863f  female  PAN13-EN               False
# ..                                ...     ...       ...                 ...
# 195  682d9b4fc0ab9c306a99f4b8af476023  female  PAN13-EN               False
# 196                           3441444       0      BLOG               False
# 197                           3287062       0      BLOG               False
# 198                           4256898       1      BLOG               False
# 199                           4178158       1      BLOG               False
#
#     expected_answer                                                nlp  \
# 0              None  (Slowly, and, gradually, ,, all, facets, of, t...
# 1              None  (What, a, wonderful, day, we, had, ., We, vent...
# 2              None  (This, text, will, discuss, the, key, variatio...
# 3              None  (It, was, a, day, of, sightseeing, for, us, !,...
# 4              None  (it, behoves, on, us, all, to, make, a, drasti...
# ..              ...                                                ...
# 195            None  (  , technology, in, schools, is, for, everyon...
# 196            None  (I, dunno, ., Sometimes, I, just, think, I, 'm...
# 197            None  (As, intelligent, as, I, am, ,, I, overlooked,...
# 198            None  (Todae, ,, Sundae, nite, ...., again, mus, thi...
# 199            None  (I, thought, this, whole, having, kids, thingy...
#
#      raw_sequence_length  n_tokens  n_lemmas  ...  n_CONJ_ConjType_Cmp  \
# 0               0.396155 -0.147564  0.171612  ...                  NaN
# 1               0.396155  0.953659  0.494392  ...                  NaN
# 2               0.396155 -0.000734  0.279205  ...                  NaN
# 3              -0.937181 -0.808298 -0.796730  ...                  NaN
# 4              -2.150859 -1.909521 -1.549885  ...                  NaN
# ..                   ...       ...       ...  ...                  ...
# 195             0.396155  0.513170 -0.258762  ...                  NaN
# 196             0.396155  1.027074  1.247547  ...                  NaN
# 197             0.396155  0.439755  0.386799  ...                  NaN
# 198             0.396155  0.880244  0.279205  ...                  NaN
# 199             0.396155  1.173904  1.247547  ...                  NaN
#
#      n_CONJ_ConjType_Oper  n_CCONJ_ConjType_Cmp  n_CCONJ_ConjType_Oper  \
# 0                     NaN              0.365078                    NaN
# 1                     NaN              1.141840                    NaN
# 2                     NaN              0.365078                    NaN
# 3                     NaN             -1.188446                    NaN
# 4                     NaN             -0.411684                    NaN
# ..                    ...                   ...                    ...
# 195                   NaN             -0.411684                    NaN
# 196                   NaN              1.141840                    NaN
# 197                   NaN             -1.188446                    NaN
# 198                   NaN              1.918602                    NaN
# 199                   NaN             -0.411684                    NaN
#
#      n_SCONJ_ConjType_Cmp  n_SCONJ_ConjType_Oper  n_ADP_AdpType_Prep  \
# 0                     NaN                    NaN                 NaN
# 1                     NaN                    NaN                 NaN
# 2                     NaN                    NaN                 NaN
# 3                     NaN                    NaN                 NaN
# 4                     NaN                    NaN                 NaN
# ..                    ...                    ...                 ...
# 195                   NaN                    NaN                 NaN
# 196                   NaN                    NaN                 NaN
# 197                   NaN                    NaN                 NaN
# 198                   NaN                    NaN                 NaN
# 199                   NaN                    NaN                 NaN
#
#      n_ADP_AdpType_Post  n_ADP_AdpType_Circ  n_ADP_AdpType_Voc
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                   NaN                 NaN                NaN
# ..                  ...                 ...                ...
# 195                 NaN                 NaN                NaN
# 196                 NaN                 NaN                NaN
# 197                 NaN                 NaN                NaN
# 198                 NaN                 NaN                NaN
# 199                 NaN                 NaN                NaN
#
# [200 rows x 1079 columns]
